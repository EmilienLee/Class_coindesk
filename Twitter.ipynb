# %% [markdown]
# # Standsard Searh #

# %%
import tweepy

# %%
from tweepy import OAuthHandler

# %%
consumer_key = 'TPX8iFkU9FqQGX9XgUKLT4owC'
consumer_secret = 'OTcEXPnWMAczs8xeHHFTS6kmi6A4coPjatqeI5ZcyXzyr8JeVc'
access_token = '839119765838843905-DBQ2MJYtlIs0FgOj8cyinf1mWbRpjZz'
access_secret = 'fWDIHczrix0NuCwKM9BTez5C3RDc8wUxfb81PDEEEJcbr'

auth = OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_secret)

api = tweepy.API(auth)

# %%
for status in tweepy.Cursor(api.home_timeline).items(10):
    print(status.text)
# Out:
# A sweet treat that comes with a little buzz https://t.co/8OOhc2UUuK
# Bridge the divide between employees at headquarters and everyone else
# https://t.co/CgDm6iYYzm
# Netanyahu flies to Moscow for talks on Syria with Putin https://t.co/lCywaWcMd1
# Rosenstein approved surveillance extension of former Trump adviser: NYT https://t.co/AUrY6Y6gWt https://t.co/UkPDmUXbT0
# A much weaker dollar could be too much of a good thing -- Heard on the Street      https://t.co/11gKYghkNg
# Why pharma ads are on the bench during this year's Super Bowl https://t.co/jtnNuckuk1 https://t.co/e1RWv4sLVR
# Creativity is not a process, it's a dance https://t.co/z38eHFkgMP https://t.co/GVtiOXj1nh
# Brand Film Festival London: Judges and venue confirmed, entry deadline nears https://t.co/jBXejoyzDu… https://t.co/WuYmwspm6w
# Especially remarkable was the 1918 flu's predilection for taking the lives of otherwise healthy young adults, as op… https://t.co/9RBxUh6Xkf
# "How the judge in Larry Nassar's case undermined justice" https://t.co/2UpPTGQYIL

# %%
query='bitcoin'
language = "en"
results = api.search(q=query, lang=language, count = 100, show_user=True ,result_type='mix')
for tweet in results:
    print (tweet.text)
# Out:
# G
#
# ========
# Earn bitcoin
# https://t.co/lnxQb5evKM
# Decentralized Video Sharing Platform Viuly Offers Video Makers Unrestricted Earnings https://t.co/Va1RWF5y08… https://t.co/gUJxYciz7f
# RT @BobsRepair: Heidi @blockchainchick is one of the leaders in the youtube crypto space. It was a real pleasure to be interviewed by her.…
# RT @esimong: 📊 Bitcoin as a a leading indicator of the Dow
# by @McClellanOsc via @trnpts
# https://t.co/BQBvO1IaOA
#
# #StockMarket #Bitcoin $D…
# RT @Douffle: IF I GOT 1K FOLLOWERS I will GIVEAWAY 1k dollars worth of #Bitcoin You must RETWEET and FOLLOW ME AND @Abhinemm to be eligible…
# RT @thenareshyadav: I plan to giveaway #1000 coins of #Electroneum on #28thFeb 👍
# For participation u need to
# #replytweet with your #ETN wa…
# U
#
# ========
# Earn bitcoin
# https://t.co/lnxQb5evKM
# @XVGClownFish @Nina_White_Paws @APompliano @XVG_Orca Verge is a badly done copy/paste project. $xvg has no more pri… https://t.co/6Ww2KmBkXR
# Bitcoin and Blockchains in Davos, Starbucks Coin, Nuclear Hacks - Fortune https://t.co/A2DJp9Gua4
# RT @iamjosephyoung: Absolutely huge. One of South Korea's largest e-commerce platform is integrating bitcoin and other cryptocurrencies wit…
# The Tell: A trusted digital currency is coming, but it’s not bitcoin, says Starbucks’ Howard Schultz: This sounds l… https://t.co/FmqEsZ55WZ
# #crypto #cryptofreebies #airdrops…
# RT @Bill_Gross: Indian housewives hold 11% of the World's gold. That is more than the reserves of USA, IMF, Switzerland and Germany put tog…
# RT @brucefenton: If you had invested $100 in Bitcoin on this day in 2011...
#
# you'd have likely sold at $200.
#
# Buying is easy, HODLing takes…
# CIG - "Men Break into House, Steal Bitcoin at Gunpoint - https://t.co/PaJFBjvi9t https://t.co/ldChjeFChz"
# Jackpot Capital Casino 50 Free Spins for New Players and New 100% Daily Bonus https://t.co/jCDJhr1CS9 Reliable… https://t.co/fiBZo4Ds1k
# RT @obizcoin: How, Where, When, and What. We got it covered. Everything you need to know about OBIZCOIN -&gt; check our FAQs -https://t.co/PiO…
# RT @AriDavidPaul: What are your favorite educational resources to give neophytes and "mid-level" cryptocurrency enthusiasts?  I'll start: h…
# "In contrast to some western merchants dropping bitcoin due to its high fees, South Korean commerce is seemingly ha… https://t.co/Q5PRepjJuZ

# %% [markdown]
# # Twitter premium and enterprise search #

# %% [markdown]
# ## source :http://benalexkeen.com/interacting-with-the-twitter-api-using-python/ ##

# %%
# !pip install searchtweets
# Out:
# Collecting searchtweets
#   Downloading searchtweets-1.2.1-py3-none-any.whl
# Requirement already satisfied: pyyaml in /home/emilien/.pyenv/versions/anaconda3-5.0.1/lib/python3.6/site-packages (from searchtweets)
# Requirement already satisfied: requests in /home/emilien/.pyenv/versions/anaconda3-5.0.1/lib/python3.6/site-packages (from searchtweets)
# Collecting tweet-parser (from searchtweets)
#   Downloading tweet_parser-1.13.0.tar.gz
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /home/emilien/.pyenv/versions/anaconda3-5.0.1/lib/python3.6/site-packages (from requests->searchtweets)
# Requirement already satisfied: idna<2.7,>=2.5 in /home/emilien/.pyenv/versions/anaconda3-5.0.1/lib/python3.6/site-packages (from requests->searchtweets)
# Requirement already satisfied: urllib3<1.23,>=1.21.1 in /home/emilien/.pyenv/versions/anaconda3-5.0.1/lib/python3.6/site-packages (from requests->searchtweets)
# Requirement already satisfied: certifi>=2017.4.17 in /home/emilien/.pyenv/versions/anaconda3-5.0.1/lib/python3.6/site-packages (from requests->searchtweets)
# Building wheels for collected packages: tweet-parser
#   Running setup.py bdist_wheel for tweet-parser ... done
#   Stored in directory: /home/emilien/.cache/pip/wheels/24/9a/8d/a7222c312d2579eddbcd0f4505d5c0dcd60dcffc876618f7eb
# Successfully built tweet-parser
# Installing collected packages: tweet-parser, searchtweets
# Successfully installed searchtweets-1.2.1 tweet-parser-1.13.0

# %%
from searchtweets import load_credentials, gen_rule_payload, load_credentials

# %%
client_key = 'TPX8iFkU9FqQGX9XgUKLT4owC'
client_secret = 'OTcEXPnWMAczs8xeHHFTS6kmi6A4coPjatqeI5ZcyXzyr8JeVc'

import base64

key_secret = '{}:{}'.format(client_key, client_secret).encode('ascii')
b64_encoded_key = base64.b64encode(key_secret)
b64_encoded_key = b64_encoded_key.decode('ascii')

# %%
import requests

base_url = 'https://api.twitter.com/'
auth_url = '{}oauth2/token'.format(base_url)

auth_headers = {
    'Authorization': 'Basic {}'.format(b64_encoded_key),
    'Content-Type': 'application/x-www-form-urlencoded;charset=UTF-8'
}

auth_data = {
    'grant_type': 'client_credentials'
}

auth_resp = requests.post(auth_url, headers=auth_headers, data=auth_data)

# %%
auth_resp.status_code
# Out:
# 200

# %%
auth_resp.json().keys()
# Out:
# dict_keys(['token_type', 'access_token'])

# %%
access_token = auth_resp.json()['access_token']

# %%
access_token
# Out:
# 'AAAAAAAAAAAAAAAAAAAAAIra4AAAAAAAdPbFxIVc550NUNM1%2B%2FPjiXDbDUE%3DuEacrkamRRvGw8i06XPDUdbFYy72TDRJNCYnZoBcTk32OtFt4s'

# %%
search_headers = {
    'Authorization': 'Bearer {}'.format(access_token)    
}

search_params = {
    'q': 'bitcoin',
    'count': 500,
    'lang': 'zh',
    'place_country':'TW'
}

search_url = '{}1.1/search/tweets.json'.format(base_url)

search_resp = requests.get(search_url, headers=search_headers, params=search_params)

# %%
search_resp
# Out:
# <Response [200]>

# %%
tweet_data = search_resp.json()

# %%
for x in tweet_data['statuses']:
    print(x['text'] + '\n')
# Out:
# 開拓新財路？ 傳三星為中資公司打造BitCoin挖礦用晶片
#
# https://t.co/my3MPfz8pw　#PC3 記者報導
# ————————————... https://t.co/LoovwPpa4H
#
# 抄底首选https://t.co/Vmqhk0AH4z  年后震荡上扬可期
#
# #Bitcoin #bitcoincrash #Ethereum #LTC
#
# 更多法币兑数字货币价格动态：https://t.co/HplXYZ1EeT https://t.co/8OslXoAkgq
#
# #Airdrop #Bitcoin #Blockchain #verdot #Ripple #XRP #Cryptocurrencies #XVG  - 加入Verdot Airdrop以获得500 VRD https://t.co/3tcpG9OHbw
#
# 美國監管烏雲籠罩，比特幣暴跌 12% 摔破 1 萬美元 https://t.co/sPkWIUzZ0q https://t.co/ySgcHHJDQS
#
# RT @Weex_com: 区块链应用再进化，https://t.co/Y76geph0WW准备好和你同行
# #BTC #Bitcoin #BCH #BitcoinCash
# 更多法币兑数字货币价格动态：https://t.co/HplXYZ1EeT https://t.co/m…
#
# 你对比特币 Bitcoin 了解有多少？看看我们的解说： https://t.co/xaBBhRw056
#
# @RSKsmart @GabrielKurman 以后会被清零吗？
#
# RT @MortGuo: 各种bitcoin大亨，业内人士都跳出来说什么“btc未来价格会是$100,000”，“现在不买btc将来一定后悔”之类的。
# 都这么明白的告诉你庄家在出货了，还有人去接盘。
#
# RT @MortGuo: 各种bitcoin大亨，业内人士都跳出来说什么“btc未来价格会是$100,000”，“现在不买btc将来一定后悔”之类的。
# 都这么明白的告诉你庄家在出货了，还有人去接盘。
#
# 各种bitcoin大亨，业内人士都跳出来说什么“btc未来价格会是$100,000”，“现在不买btc将来一定后悔”之类的。
# 都这么明白的告诉你庄家在出货了，还有人去接盘。
#
# 比特币质疑者的三个谎言 https://t.co/1JEWpZ4rqw
#
# 比特币（BTC/ USD）可以交易SimpleFX。 https://t.co/HcJy1YrlGj #FX #Bitcoin #MT4
#
# RT @WallStTV: 比特幣瘋了！你會瘋嗎？ https://t.co/czGIYKmIAf https://t.co/PHHLTyYCK5
#
# 我剛剛在WCX國際貨幣交易平台上註冊！註冊 &amp; 賺取50個WCX代幣。 @wcxofficial #bitcoin https://t.co/Ec5eZiiTEq
#
# RT @kbflF5: 除咗好似政府咁勸誡大家 #唔識唔好買 之外，我地仲會選擇開班同大家一齊認識 （真係搞緊，歡迎追數）
#
# 錢家有道 The Chin Family
# 首次代幣發行（ICO）、比特幣（Bitcoin）及其他「加密貨幣」... https://t.co/Z2GCj…
#
# RT @iyouport_news: ⚠️#bitcoin 著名的《Mastering Bitcoin》（《精通比特币》）一书中有段Python代码有误（https://t.co/qwD3li3hWO），这个错误有极高的概率会根据一个正确的私钥生成一个错误的压缩公钥，从而产生一…
#
# RT @iyouport_news: ⚠️#bitcoin 著名的《Mastering Bitcoin》（《精通比特币》）一书中有段Python代码有误（https://t.co/qwD3li3hWO），这个错误有极高的概率会根据一个正确的私钥生成一个错误的压缩公钥，从而产生一…
#
# RT @iyouport_news: ⚠️#bitcoin 著名的《Mastering Bitcoin》（《精通比特币》）一书中有段Python代码有误（https://t.co/qwD3li3hWO），这个错误有极高的概率会根据一个正确的私钥生成一个错误的压缩公钥，从而产生一…
#
# RT @iyouport_news: ⚠️#bitcoin 著名的《Mastering Bitcoin》（《精通比特币》）一书中有段Python代码有误（https://t.co/qwD3li3hWO），这个错误有极高的概率会根据一个正确的私钥生成一个错误的压缩公钥，从而产生一…
#
# RT @gg226600: @CNS1952 英媒: 倾家荡产的泛亚受害者抗议政府背书的诈骗 #习近平 #泛亚 #郭文贵 #李克强 #Federer #AusOpen #IKEA #FedererVsCilic #AustralianOpen #SundayBlogShare…
#
# RT @gg226600: @CNS1952 英媒: 倾家荡产的泛亚受害者抗议政府背书的诈骗 #习近平 #泛亚 #郭文贵 #李克强 #Federer #AusOpen #IKEA #FedererVsCilic #AustralianOpen #SundayBlogShare…
#
# RT @gg226600: @CNS1952 英媒: 倾家荡产的泛亚受害者抗议政府背书的诈骗 #习近平 #泛亚 #郭文贵 #李克强 #Federer #AusOpen #IKEA #FedererVsCilic #AustralianOpen #SundayBlogShare…
#
# RT @gg226600: @CNS1952 英媒: 倾家荡产的泛亚受害者抗议政府背书的诈骗 #习近平 #泛亚 #郭文贵 #李克强 #Federer #AusOpen #IKEA #FedererVsCilic #AustralianOpen #SundayBlogShare…
#
# RT
#
# RT @gg226600: @CNS1952 英媒: 倾家荡产的泛亚受害者抗议政府背书的诈骗 #习近平 #泛亚 #郭文贵 #李克强 #Federer #AusOpen #IKEA #FedererVsCilic #AustralianOpen #SundayBlogShare…
#
# @spacemining_io 现在是什么情况？ 12个小时 bitcoin还没有到账！！ 还没有发币。。。
#
# 区块链应用再进化，https://t.co/Y76geph0WW准备好和你同行
# #BTC #Bitcoin #BCH #BitcoinCash
# 更多法币兑数字货币价格动态：https://t.co/HplXYZ1EeT https://t.co/m1xohHH8fG
#
# 《Mastering Bitcoin》中的錯誤代碼可能會導致你的比特幣丟失 匿名讀者 寫道 "著名的 https://t.co/1YfXeMUyg2
#
# 英國首宗Bitcoin劫案　匪徒持槍威嚇事主過數 https://t.co/fNw5zvFrUU
#
# 日本已经有(虚拟货币)交易所被发现在使用机器人自买自卖、单方面拉抬价格。 https://t.co/8zd6Pf8cXF https://t.co/zS6SlIXwyL
#
# RT @gg226600: @CNS1952 英媒: 倾家荡产的泛亚受害者抗议政府背书的诈骗 #习近平 #泛亚 #郭文贵 #李克强 #Federer #AusOpen #IKEA #FedererVsCilic #AustralianOpen #SundayBlogShare…
#
# RT @gg226600: @CNS1952 英媒: 倾家荡产的泛亚受害者抗议政府背书的诈骗 #习近平 #泛亚 #郭文贵 #李克强 #Federer #AusOpen #IKEA #FedererVsCilic #AustralianOpen #SundayBlogShare…
#
# RT @gg226600: @CNS1952 英媒: 倾家荡产的泛亚受害者抗议政府背书的诈骗 #习近平 #泛亚 #郭文贵 #李克强 #Federer #AusOpen #IKEA #FedererVsCilic #AustralianOpen #SundayBlogShare…
#
# RT @gg226600: @CNS1952 英媒: 倾家荡产的泛亚受害者抗议政府背书的诈骗 #习近平 #泛亚 #郭文贵 #李克强 #Federer #AusOpen #IKEA #FedererVsCilic #AustralianOpen #SundayBlogShare…
#
# RT @gg226600: @CNS1952 英媒: 倾家荡产的泛亚受害者抗议政府背书的诈骗 #习近平 #泛亚 #郭文贵 #李克强 #Federer #AusOpen #IKEA #FedererVsCilic #AustralianOpen #SundayBlogShare…
#
# RT @gg226600: @CNS1952 英媒: 倾家荡产的泛亚受害者抗议政府背书的诈骗 #习近平 #泛亚 #郭文贵 #李克强 #Federer #AusOpen #IKEA #FedererVsCilic #AustralianOpen #SundayBlogShare…
#
# 我剛剛在WCX國際貨幣交易平台上註冊！註冊 &amp; 賺取50個WCX代幣。 @wcxofficial #bitcoin https://t.co/Pipjb3BlEh
#
# RT @gg226600: @CNS1952 英媒: 倾家荡产的泛亚受害者抗议政府背书的诈骗 #习近平 #泛亚 #郭文贵 #李克强 #Federer #AusOpen #IKEA #FedererVsCilic #AustralianOpen #SundayBlogShare…
#
# RT @gg226600: @CNS1952 英媒: 倾家荡产的泛亚受害者抗议政府背书的诈骗 #习近平 #泛亚 #郭文贵 #李克强 #Federer #AusOpen #IKEA #FedererVsCilic #AustralianOpen #SundayBlogShare…
#
# 第五个：12月31日，BUM（比特币铀）；
#
# 第六个：2018年1月2日，Bitcoin Cash Plus（比特币现金增强版）；
#
# 第七个：Bitcoin Silver（比特币白银）；
#
# 第八个：Bitcoin X（比特无限）。
#
# RT @gg226600: @CNS1952 英媒: 倾家荡产的泛亚受害者抗议政府背书的诈骗 #习近平 #泛亚 #郭文贵 #李克强 #Federer #AusOpen #IKEA #FedererVsCilic #AustralianOpen #SundayBlogShare…
#
# RT @gg226600: @CNS1952 英媒: 倾家荡产的泛亚受害者抗议政府背书的诈骗 #习近平 #泛亚 #郭文贵 #李克强 #Federer #AusOpen #IKEA #FedererVsCilic #AustralianOpen #SundayBlogShare…
#
# RT @gg226600: @CNS1952 英媒: 倾家荡产的泛亚受害者抗议政府背书的诈骗 #习近平 #泛亚 #郭文贵 #李克强 #Federer #AusOpen #IKEA #FedererVsCilic #AustralianOpen #SundayBlogShare…
#
# RT @gg226600: @CNS1952 英媒: 倾家荡产的泛亚受害者抗议政府背书的诈骗 #习近平 #泛亚 #郭文贵 #李克强 #Federer #AusOpen #IKEA #FedererVsCilic #AustralianOpen #SundayBlogShare…
#
# RT @gg226600: @CNS1952 英媒: 倾家荡产的泛亚受害者抗议政府背书的诈骗 #习近平 #泛亚 #郭文贵 #李克强 #Federer #AusOpen #IKEA #FedererVsCilic #AustralianOpen #SundayBlogShare…
#
# NETELLER还支持比特币支付. https://t.co/lPP3dFW902 #Bitcoin #NETELLER
#
# 卡巴斯基創辦人宣稱比特幣是美國情報單位的專案，真的嗎？ https://t.co/1QMbZGG0XG
#
# RT @gg226600: @CNS1952 英媒: 倾家荡产的泛亚受害者抗议政府背书的诈骗 #习近平 #泛亚 #郭文贵 #李克强 #Federer #AusOpen #IKEA #FedererVsCilic #AustralianOpen #SundayBlogShare…
#
# RT @gg226600: @CNS1952 英媒: 倾家荡产的泛亚受害者抗议政府背书的诈骗 #习近平 #泛亚 #郭文贵 #李克强 #Federer #AusOpen #IKEA #FedererVsCilic #AustralianOpen #SundayBlogShare…
#
# RT @gg226600: @CNS1952 英媒: 倾家荡产的泛亚受害者抗议政府背书的诈骗 #习近平 #泛亚 #郭文贵 #李克强 #Federer #AusOpen #IKEA #FedererVsCilic #AustralianOpen #SundayBlogShare…
#
# RT @gg226600: @CNS1952 英媒: 倾家荡产的泛亚受害者抗议政府背书的诈骗 #习近平 #泛亚 #郭文贵 #李克强 #Federer #AusOpen #IKEA #FedererVsCilic #AustralianOpen #SundayBlogShare…
#
# #叙利亚 求武器，求经费……恐怖分子也玩代币众筹了。#比特币 #Bitcoin https://t.co/G19KGBFPJn
#
# RT @gg226600: @CNS1952 英媒: 倾家荡产的泛亚受害者抗议政府背书的诈骗 #习近平 #泛亚 #郭文贵 #李克强 #Federer #AusOpen #IKEA #FedererVsCilic #AustralianOpen #SundayBlogShare…
#
# RT @gg226600: @CNS1952 英媒: 倾家荡产的泛亚受害者抗议政府背书的诈骗 #习近平 #泛亚 #郭文贵 #李克强 #Federer #AusOpen #IKEA #FedererVsCilic #AustralianOpen #SundayBlogShare…
#
# RT @gg226600: @CNS1952 英媒: 倾家荡产的泛亚受害者抗议政府背书的诈骗 #习近平 #泛亚 #郭文贵 #李克强 #Federer #AusOpen #IKEA #FedererVsCilic #AustralianOpen #SundayBlogShare…
#
# RT @gg226600: @CNS1952 英媒: 倾家荡产的泛亚受害者抗议政府背书的诈骗 #习近平 #泛亚 #郭文贵 #李克强 #Federer #AusOpen #IKEA #FedererVsCilic #AustralianOpen #SundayBlogShare…
#
# @China__Newz 英媒: 倾家荡产的泛亚受害者抗议政府背书的诈骗 #习近平 #泛亚 #郭文贵 #李克强 #Federer #AusOpen #IKEA #FedererVsCilic #AustralianOpen… https://t.co/f4jWQCWPH8
#
# RT @s3FopWYMFk7EbpU: @China__Newz 英媒: 倾家荡产的泛亚受害者抗议政府背书的诈骗 #习近平 #泛亚 #郭文贵 #李克强 #Federer #AusOpen #IKEA #FedererVsCilic #AustralianOpen #Sunda…

# %% [markdown]
# # twitter offcial step

# %%
from searchtweets import load_credentials

# %%
premium_search_args = load_credentials(filename="/home/emilien/bb105/.twitter_keys.yaml",
                                       yaml_key="search_tweets_premium",
                                       env_overwrite=False)

# %%
rule = gen_rule_payload("bitcoin", results_per_call=100) # testing with a sandbox account
print(rule)
# Out:
# {"query": "bitcoin", "maxResults": 100}

# %%
from searchtweets import collect_results

# %%
tweets = collect_results(rule,max_results=100,result_stream_args=premium_search_args)

# %%
tweets
# Out:
# [{'contributors': None,
#   'coordinates': None,
#   'created_at': 'Wed Jan 31 08:32:02 +0000 2018',
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'urls': [{'display_url': 'crwd.fr/2E2IU0q',
#      'expanded_url': 'http://crwd.fr/2E2IU0q',
#      'indices': [0, 23],
#      'url': 'https://t.co/kZCKmIig4A'},
#     {'display_url': 'twitter.com/i/web/status/9…',
#      'expanded_url': 'https://twitter.com/i/web/status/958618867139600389',
#      'indices': [117, 140],
#      'url': 'https://t.co/5Oko2kiofQ'}],
#    'user_mentions': []},
#   'extended_tweet': {'display_text_range': [0, 192],
#    'entities': {'hashtags': [{'indices': [153, 160], 'text': 'crypto'},
#      {'indices': [161, 173], 'text': 'pumpanddump'},
#      {'indices': [174, 182], 'text': 'bitcoin'},
#      {'indices': [183, 192], 'text': 'altcoins'}],
#     'symbols': [],
#     'urls': [{'display_url': 'crwd.fr/2E2IU0q',
#       'expanded_url': 'http://crwd.fr/2E2IU0q',
#       'indices': [0, 23],
#       'url': 'https://t.co/kZCKmIig4A'}],
#     'user_mentions': []},
#    'full_text': 'https://t.co/kZCKmIig4A  New pump and dump telegram group. NO PRE PUMP. NO RANK BS. EQUAL CHANCE FOR ALL TO MAKE GREAT GAINS!! First pump at 500 members #crypto #pumpanddump #bitcoin #altcoins'},
#   'favorite_count': 0,
#   'favorited': False,
#   'filter_level': 'low',
#   'geo': None,
#   'id': 958618867139600389,
#   'id_str': '958618867139600389',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': False,
#   'lang': 'en',
#   'matching_rules': [{'tag': None}],
#   'place': None,
#   'possibly_sensitive': False,
#   'quote_count': 0,
#   'reply_count': 0,
#   'retweet_count': 0,
#   'retweeted': False,
#   'source': '<a href="http://www.crowdfireapp.com" rel="nofollow">Crowdfire - Go Big</a>',
#   'text': 'https://t.co/kZCKmIig4A  New pump and dump telegram group. NO PRE PUMP. NO RANK BS. EQUAL CHANCE FOR ALL TO MAKE GR… https://t.co/5Oko2kiofQ',
#   'truncated': True,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Sun Dec 24 19:54:21 +0000 2017',
#    'default_profile': True,
#    'default_profile_image': False,
#    'description': "https://t.me/pumpkingpins please join and share the link. We're making a group without ranks etc",
#    'favourites_count': 191,
#    'follow_request_sent': None,
#    'followers_count': 79,
#    'following': None,
#    'friends_count': 448,
#    'geo_enabled': False,
#    'id': 945019834840092672,
#    'id_str': '945019834840092672',
#    'is_translator': False,
#    'lang': 'en',
#    'listed_count': 1,
#    'location': 'The moon',
#    'name': 'Pump Kingpins',
#    'notifications': None,
#    'profile_background_color': 'F5F8FA',
#    'profile_background_image_url': '',
#    'profile_background_image_url_https': '',
#    'profile_background_tile': False,
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/945019834840092672/1515917498',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/956212949705687041/Y-MtDFF0_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/956212949705687041/Y-MtDFF0_normal.jpg',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'protected': False,
#    'screen_name': 'pumpkingpins',
#    'statuses_count': 304,
#    'time_zone': 'Pacific Time (US & Canada)',
#    'translator_type': 'none',
#    'url': 'https://t.me/pumpkingpins',
#    'utc_offset': -28800,
#    'verified': False}},
#  {'contributors': None,
#   'coordinates': None,
#   'created_at': 'Wed Jan 31 08:32:02 +0000 2018',
#   'entities': {'hashtags': [{'indices': [107, 111], 'text': 'edo'},
#     {'indices': [112, 121], 'text': 'coinbase'},
#     {'indices': [122, 129], 'text': 'wallet'},
#     {'indices': [130, 137], 'text': 'crypto'}],
#    'symbols': [],
#    'urls': [{'display_url': 'ibtimes.com/move-over-coin…',
#      'expanded_url': 'http://www.ibtimes.com/move-over-coinbase-eidoo-has-huge-potential-cryptocurrency-space-2643155',
#      'indices': [83, 106],
#      'url': 'https://t.co/pqUY2sJAU2'}],
#    'user_mentions': [{'id': 625513,
#      'id_str': '625513',
#      'indices': [3, 19],
#      'name': 'Amanda Lorenzani',
#      'screen_name': 'AmandaLorenzani'},
#     {'id': 843372242381783044,
#      'id_str': '843372242381783044',
#      'indices': [73, 82],
#      'name': 'Eidoo',
#      'screen_name': 'eidoo_io'}]},
#   'favorite_count': 0,
#   'favorited': False,
#   'filter_level': 'low',
#   'geo': None,
#   'id': 958618867110064128,
#   'id_str': '958618867110064128',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': False,
#   'lang': 'en',
#   'matching_rules': [{'tag': None}],
#   'place': None,
#   'possibly_sensitive': False,
#   'quote_count': 0,
#   'reply_count': 0,
#   'retweet_count': 0,
#   'retweeted': False,
#   'retweeted_status': {'contributors': None,
#    'coordinates': None,
#    'created_at': 'Sat Jan 20 17:46:45 +0000 2018',
#    'entities': {'hashtags': [{'indices': [86, 90], 'text': 'edo'},
#      {'indices': [91, 100], 'text': 'coinbase'},
#      {'indices': [101, 108], 'text': 'wallet'}],
#     'symbols': [],
#     'urls': [{'display_url': 'ibtimes.com/move-over-coin…',
#       'expanded_url': 'http://www.ibtimes.com/move-over-coinbase-eidoo-has-huge-potential-cryptocurrency-space-2643155',
#       'indices': [62, 85],
#       'url': 'https://t.co/pqUY2sJAU2'},
#      {'display_url': 'twitter.com/i/web/status/9…',
#       'expanded_url': 'https://twitter.com/i/web/status/954772196412489728',
#       'indices': [110, 133],
#       'url': 'https://t.co/DhBiJZXQ6l'}],
#     'user_mentions': [{'id': 843372242381783044,
#       'id_str': '843372242381783044',
#       'indices': [52, 61],
#       'name': 'Eidoo',
#       'screen_name': 'eidoo_io'}]},
#    'extended_tweet': {'display_text_range': [0, 147],
#     'entities': {'hashtags': [{'indices': [86, 90], 'text': 'edo'},
#       {'indices': [91, 100], 'text': 'coinbase'},
#       {'indices': [101, 108], 'text': 'wallet'},
#       {'indices': [109, 116], 'text': 'crypto'},
#       {'indices': [117, 126], 'text': 'Ethereum'},
#       {'indices': [127, 138], 'text': 'blockchain'},
#       {'indices': [139, 147], 'text': 'bitcoin'}],
#      'symbols': [],
#      'urls': [{'display_url': 'ibtimes.com/move-over-coin…',
#        'expanded_url': 'http://www.ibtimes.com/move-over-coinbase-eidoo-has-huge-potential-cryptocurrency-space-2643155',
#        'indices': [62, 85],
#        'url': 'https://t.co/pqUY2sJAU2'}],
#      'user_mentions': [{'id': 843372242381783044,
#        'id_str': '843372242381783044',
#        'indices': [52, 61],
#        'name': 'Eidoo',
#        'screen_name': 'eidoo_io'}]},
#     'full_text': 'interesting predictions here about the potential of @eidoo_io https://t.co/pqUY2sJAU2 #edo #coinbase #wallet #crypto #Ethereum #blockchain #bitcoin'},
#    'favorite_count': 68,
#    'favorited': False,
#    'filter_level': 'low',
#    'geo': None,
#    'id': 954772196412489728,
#    'id_str': '954772196412489728',
#    'in_reply_to_screen_name': None,
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'is_quote_status': False,
#    'lang': 'en',
#    'place': None,
#    'possibly_sensitive': False,
#    'quote_count': 0,
#    'reply_count': 3,
#    'retweet_count': 407,
#    'retweeted': False,
#    'source': '<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>',
#    'text': 'interesting predictions here about the potential of @eidoo_io https://t.co/pqUY2sJAU2 #edo #coinbase #wallet… https://t.co/DhBiJZXQ6l',
#    'truncated': True,
#    'user': {'contributors_enabled': False,
#     'created_at': 'Thu Jan 11 13:13:23 +0000 2007',
#     'default_profile': False,
#     'default_profile_image': False,
#     'description': 'Founder, The Good PR Agency : Slashers.me : TechCrunch Italy : Fox & Rose',
#     'favourites_count': 718,
#     'follow_request_sent': None,
#     'followers_count': 3458,
#     'following': None,
#     'friends_count': 861,
#     'geo_enabled': False,
#     'id': 625513,
#     'id_str': '625513',
#     'is_translator': False,
#     'lang': 'en',
#     'listed_count': 153,
#     'location': 'Brighton, London, Milan, Rome',
#     'name': 'Amanda Lorenzani',
#     'notifications': None,
#     'profile_background_color': '1A1B1F',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme9/bg.gif',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme9/bg.gif',
#     'profile_background_tile': False,
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/625513/1481383140',
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/807591045441720320/hxXJTfoY_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/807591045441720320/hxXJTfoY_normal.jpg',
#     'profile_link_color': '2FC2EF',
#     'profile_sidebar_border_color': '181A1E',
#     'profile_sidebar_fill_color': '252429',
#     'profile_text_color': '666666',
#     'profile_use_background_image': True,
#     'protected': False,
#     'screen_name': 'AmandaLorenzani',
#     'statuses_count': 3369,
#     'time_zone': 'London',
#     'translator_type': 'none',
#     'url': 'https://www.getrevue.co/profile/amandalorenzani',
#     'utc_offset': 0,
#     'verified': False}},
#   'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#   'text': 'RT @AmandaLorenzani: interesting predictions here about the potential of @eidoo_io https://t.co/pqUY2sJAU2 #edo #coinbase #wallet #crypto #…',
#   'truncated': False,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Wed Jan 31 00:28:10 +0000 2018',
#    'default_profile': True,
#    'default_profile_image': False,
#    'description': None,
#    'favourites_count': 0,
#    'follow_request_sent': None,
#    'followers_count': 1,
#    'following': None,
#    'friends_count': 21,
#    'geo_enabled': False,
#    'id': 958497097115979776,
#    'id_str': '958497097115979776',
#    'is_translator': False,
#    'lang': 'en',
#    'listed_count': 0,
#    'location': None,
#    'name': 'Almeta Nasson ii',
#    'notifications': None,
#    'profile_background_color': 'F5F8FA',
#    'profile_background_image_url': '',
#    'profile_background_image_url_https': '',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/958499261368414208/n47gLtdx_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/958499261368414208/n47gLtdx_normal.jpg',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'protected': False,
#    'screen_name': 'AlmetaNassonii5',
#    'statuses_count': 62,
#    'time_zone': None,
#    'translator_type': 'none',
#    'url': None,
#    'utc_offset': None,
#    'verified': False}},
#  {'contributors': None,
#   'coordinates': None,
#   'created_at': 'Wed Jan 31 08:32:02 +0000 2018',
#   'entities': {'hashtags': [{'indices': [33, 41], 'text': 'Paccoin'},
#     {'indices': [42, 51], 'text': 'Giveaway'},
#     {'indices': [69, 78], 'text': 'PACCOINS'},
#     {'indices': [79, 85], 'text': 'PRIZE'}],
#    'symbols': [],
#    'urls': [],
#    'user_mentions': [{'id': 952420428932440064,
#      'id_str': '952420428932440064',
#      'indices': [3, 12],
#      'name': 'vkymunir',
#      'screen_name': 'vkymunir'}]},
#   'favorite_count': 0,
#   'favorited': False,
#   'filter_level': 'low',
#   'geo': None,
#   'id': 958618866933940224,
#   'id_str': '958618866933940224',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': False,
#   'lang': 'en',
#   'matching_rules': [{'tag': None}],
#   'place': None,
#   'quote_count': 0,
#   'reply_count': 0,
#   'retweet_count': 0,
#   'retweeted': False,
#   'retweeted_status': {'contributors': None,
#    'coordinates': None,
#    'created_at': 'Wed Jan 31 06:00:24 +0000 2018',
#    'entities': {'hashtags': [{'indices': [19, 27], 'text': 'Paccoin'},
#      {'indices': [28, 37], 'text': 'Giveaway'},
#      {'indices': [55, 64], 'text': 'PACCOINS'},
#      {'indices': [65, 71], 'text': 'PRIZE'}],
#     'symbols': [],
#     'urls': [{'display_url': 'twitter.com/i/web/status/9…',
#       'expanded_url': 'https://twitter.com/i/web/status/958580704111144960',
#       'indices': [117, 140],
#       'url': 'https://t.co/Ex4T3oTF66'}],
#     'user_mentions': []},
#    'extended_tweet': {'display_text_range': [0, 273],
#     'entities': {'hashtags': [{'indices': [19, 27], 'text': 'Paccoin'},
#       {'indices': [28, 37], 'text': 'Giveaway'},
#       {'indices': [55, 64], 'text': 'PACCOINS'},
#       {'indices': [65, 71], 'text': 'PRIZE'},
#       {'indices': [158, 165], 'text': 'Winner'},
#       {'indices': [249, 257], 'text': 'Bitcoin'},
#       {'indices': [258, 273], 'text': 'cryptocurrency'}],
#      'symbols': [],
#      'urls': [],
#      'user_mentions': []},
#     'full_text': '📢MEGA Announcement #Paccoin #Giveaway Prize is 2500000 #PACCOINS #PRIZE\n📈💰🚀\nConditions: \n1 - Follow Subscribe to us\n2 - Retweet and like this post\n\nThe Lucky #Winner will randomly be selected at the end of the week through our online server. Follow #Bitcoin #cryptocurrency'},
#    'favorite_count': 112,
#    'favorited': False,
#    'filter_level': 'low',
#    'geo': None,
#    'id': 958580704111144960,
#    'id_str': '958580704111144960',
#    'in_reply_to_screen_name': None,
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'is_quote_status': False,
#    'lang': 'en',
#    'place': None,
#    'quote_count': 0,
#    'reply_count': 8,
#    'retweet_count': 122,
#    'retweeted': False,
#    'source': '<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>',
#    'text': '📢MEGA Announcement #Paccoin #Giveaway Prize is 2500000 #PACCOINS #PRIZE\n📈💰🚀\nConditions: \n1 - Follow Subscribe to us… https://t.co/Ex4T3oTF66',
#    'truncated': True,
#    'user': {'contributors_enabled': False,
#     'created_at': 'Sun Jan 14 06:01:40 +0000 2018',
#     'default_profile': True,
#     'default_profile_image': False,
#     'description': 'Crypto Billionaire',
#     'favourites_count': 19,
#     'follow_request_sent': None,
#     'followers_count': 1198,
#     'following': None,
#     'friends_count': 119,
#     'geo_enabled': False,
#     'id': 952420428932440064,
#     'id_str': '952420428932440064',
#     'is_translator': False,
#     'lang': 'en',
#     'listed_count': 4,
#     'location': 'Pakistan',
#     'name': 'vkymunir',
#     'notifications': None,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': '',
#     'profile_background_image_url_https': '',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/952442285928611840/UKvue0V9_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/952442285928611840/UKvue0V9_normal.jpg',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'protected': False,
#     'screen_name': 'vkymunir',
#     'statuses_count': 122,
#     'time_zone': None,
#     'translator_type': 'none',
#     'url': None,
#     'utc_offset': None,
#     'verified': False}},
#   'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#   'text': 'RT @vkymunir: 📢MEGA Announcement #Paccoin #Giveaway Prize is 2500000 #PACCOINS #PRIZE\n📈💰🚀\nConditions: \n1 - Follow Subscribe to us\n2 - Retwe…',
#   'truncated': False,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Sat Dec 23 07:20:37 +0000 2017',
#    'default_profile': True,
#    'default_profile_image': False,
#    'description': 'moon🌕',
#    'favourites_count': 97,
#    'follow_request_sent': None,
#    'followers_count': 20,
#    'following': None,
#    'friends_count': 28,
#    'geo_enabled': False,
#    'id': 944467763552075777,
#    'id_str': '944467763552075777',
#    'is_translator': False,
#    'lang': 'en',
#    'listed_count': 0,
#    'location': None,
#    'name': 'zacketson',
#    'notifications': None,
#    'profile_background_color': 'F5F8FA',
#    'profile_background_image_url': '',
#    'profile_background_image_url_https': '',
#    'profile_background_tile': False,
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/944467763552075777/1515825621',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/956175634547408896/TbUnr5Fk_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/956175634547408896/TbUnr5Fk_normal.jpg',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'protected': False,
#    'screen_name': 'gonna_moon',
#    'statuses_count': 448,
#    'time_zone': 'Pacific Time (US & Canada)',
#    'translator_type': 'none',
#    'url': None,
#    'utc_offset': -28800,
#    'verified': False}},
#  {'contributors': None,
#   'coordinates': None,
#   'created_at': 'Wed Jan 31 08:32:02 +0000 2018',
#   'entities': {'hashtags': [{'indices': [89, 99], 'text': 'DIGITIMES'}],
#    'symbols': [],
#    'urls': [{'display_url': 'digitimes.com/news/a20180131…',
#      'expanded_url': 'http://www.digitimes.com/news/a20180131PD201.html',
#      'indices': [100, 123],
#      'url': 'https://t.co/wjsP8je6UO'}],
#    'user_mentions': [{'id': 153340954,
#      'id_str': '153340954',
#      'indices': [3, 19],
#      'name': 'DIGITIMES, Inc.',
#      'screen_name': 'DigitimesDotCom'}]},
#   'favorite_count': 0,
#   'favorited': False,
#   'filter_level': 'low',
#   'geo': None,
#   'id': 958618866677989382,
#   'id_str': '958618866677989382',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': False,
#   'lang': 'en',
#   'matching_rules': [{'tag': None}],
#   'place': None,
#   'possibly_sensitive': False,
#   'quote_count': 0,
#   'reply_count': 0,
#   'retweet_count': 0,
#   'retweeted': False,
#   'retweeted_status': {'contributors': None,
#    'coordinates': None,
#    'created_at': 'Wed Jan 31 08:31:45 +0000 2018',
#    'entities': {'hashtags': [{'indices': [68, 78], 'text': 'DIGITIMES'}],
#     'symbols': [],
#     'urls': [{'display_url': 'digitimes.com/news/a20180131…',
#       'expanded_url': 'http://www.digitimes.com/news/a20180131PD201.html',
#       'indices': [79, 102],
#       'url': 'https://t.co/wjsP8je6UO'}],
#     'user_mentions': []},
#    'favorite_count': 0,
#    'favorited': False,
#    'filter_level': 'low',
#    'geo': None,
#    'id': 958618795823677440,
#    'id_str': '958618795823677440',
#    'in_reply_to_screen_name': None,
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'is_quote_status': False,
#    'lang': 'en',
#    'place': None,
#    'possibly_sensitive': False,
#    'quote_count': 0,
#    'reply_count': 0,
#    'retweet_count': 1,
#    'retweeted': False,
#    'source': '<a href="http://www.digitimes.com/index.asp" rel="nofollow">DIGITIMES CMS</a>',
#    'text': 'Samsung reportedly enters volume production for Bitcoin mining ASIC #DIGITIMES https://t.co/wjsP8je6UO',
#    'truncated': False,
#    'user': {'contributors_enabled': False,
#     'created_at': 'Tue Jun 08 08:43:11 +0000 2010',
#     'default_profile': True,
#     'default_profile_image': False,
#     'description': 'The leading media outlet for the global IT and high-tech supply chain',
#     'favourites_count': 1,
#     'follow_request_sent': None,
#     'followers_count': 2193,
#     'following': None,
#     'friends_count': 50,
#     'geo_enabled': False,
#     'id': 153340954,
#     'id_str': '153340954',
#     'is_translator': False,
#     'lang': 'en',
#     'listed_count': 161,
#     'location': 'Taiwan',
#     'name': 'DIGITIMES, Inc.',
#     'notifications': None,
#     'profile_background_color': 'C0DEED',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/153340954/1502689921',
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/599041832941539328/FVeLle2R_normal.png',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/599041832941539328/FVeLle2R_normal.png',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'protected': False,
#     'screen_name': 'DigitimesDotCom',
#     'statuses_count': 17782,
#     'time_zone': 'Taipei',
#     'translator_type': 'none',
#     'url': 'http://www.digitimes.com',
#     'utc_offset': 28800,
#     'verified': False}},
#   'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#   'text': 'RT @DigitimesDotCom: Samsung reportedly enters volume production for Bitcoin mining ASIC #DIGITIMES https://t.co/wjsP8je6UO',
#   'truncated': False,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Mon Feb 25 03:30:31 +0000 2013',
#    'default_profile': True,
#    'default_profile_image': False,
#    'description': 'Rodney Chan is Managing Editor at DIGITIMES',
#    'favourites_count': 35,
#    'follow_request_sent': None,
#    'followers_count': 86,
#    'following': None,
#    'friends_count': 72,
#    'geo_enabled': True,
#    'id': 1217182062,
#    'id_str': '1217182062',
#    'is_translator': False,
#    'lang': 'en',
#    'listed_count': 3,
#    'location': 'Taipei',
#    'name': 'Rodney Chan',
#    'notifications': None,
#    'profile_background_color': 'C0DEED',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/378800000667831430/887dc53dfa226b568364a89d89d0d4d1_normal.jpeg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/378800000667831430/887dc53dfa226b568364a89d89d0d4d1_normal.jpeg',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'protected': False,
#    'screen_name': 'RC_DIGITIMES',
#    'statuses_count': 9267,
#    'time_zone': 'Taipei',
#    'translator_type': 'none',
#    'url': 'http://www.digitimes.com',
#    'utc_offset': 28800,
#    'verified': False}},
#  {'contributors': None,
#   'coordinates': None,
#   'created_at': 'Wed Jan 31 08:32:02 +0000 2018',
#   'entities': {'hashtags': [{'indices': [28, 36], 'text': 'bitcoin'},
#     {'indices': [39, 54], 'text': 'cryptocurrency'},
#     {'indices': [55, 61], 'text': 'Coins'},
#     {'indices': [62, 77], 'text': 'BitcoinPrivate'},
#     {'indices': [94, 99], 'text': 'SOTU'},
#     {'indices': [100, 116], 'text': 'StateofOurUnion'}],
#    'symbols': [],
#    'urls': [],
#    'user_mentions': [{'id': 831796279156015108,
#      'id_str': '831796279156015108',
#      'indices': [3, 13],
#      'name': 'Economic Divide',
#      'screen_name': 'EDPressTV'},
#     {'id': 3367334171,
#      'id_str': '3367334171',
#      'indices': [78, 84],
#      'name': 'Bitcoin News',
#      'screen_name': 'BTCTN'},
#     {'id': 357312062,
#      'id_str': '357312062',
#      'indices': [85, 93],
#      'name': 'Bitcoin',
#      'screen_name': 'Bitcoin'},
#     {'id': 437732648,
#      'id_str': '437732648',
#      'indices': [117, 130],
#      'name': 'Kaveh Taghvai',
#      'screen_name': 'KavehTaghvai'}]},
#   'favorite_count': 0,
#   'favorited': False,
#   'filter_level': 'low',
#   'geo': None,
#   'id': 958618866195881984,
#   'id_str': '958618866195881984',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': False,
#   'lang': 'en',
#   'matching_rules': [{'tag': None}],
#   'place': None,
#   'quote_count': 0,
#   'reply_count': 0,
#   'retweet_count': 0,
#   'retweeted': False,
#   'retweeted_status': {'contributors': None,
#    'coordinates': None,
#    'created_at': 'Wed Jan 31 08:28:28 +0000 2018',
#    'display_text_range': [0, 140],
#    'entities': {'hashtags': [{'indices': [13, 21], 'text': 'bitcoin'},
#      {'indices': [24, 39], 'text': 'cryptocurrency'},
#      {'indices': [40, 46], 'text': 'Coins'},
#      {'indices': [47, 62], 'text': 'BitcoinPrivate'},
#      {'indices': [79, 84], 'text': 'SOTU'},
#      {'indices': [85, 101], 'text': 'StateofOurUnion'}],
#     'symbols': [],
#     'urls': [{'display_url': 'twitter.com/i/web/status/9…',
#       'expanded_url': 'https://twitter.com/i/web/status/958617967268376577',
#       'indices': [117, 140],
#       'url': 'https://t.co/OKC4Bzdouz'}],
#     'user_mentions': [{'id': 3367334171,
#       'id_str': '3367334171',
#       'indices': [63, 69],
#       'name': 'Bitcoin News',
#       'screen_name': 'BTCTN'},
#      {'id': 357312062,
#       'id_str': '357312062',
#       'indices': [70, 78],
#       'name': 'Bitcoin',
#       'screen_name': 'Bitcoin'},
#      {'id': 437732648,
#       'id_str': '437732648',
#       'indices': [102, 115],
#       'name': 'Kaveh Taghvai',
#       'screen_name': 'KavehTaghvai'}]},
#    'extended_tweet': {'display_text_range': [0, 140],
#     'entities': {'hashtags': [{'indices': [13, 21], 'text': 'bitcoin'},
#       {'indices': [24, 39], 'text': 'cryptocurrency'},
#       {'indices': [40, 46], 'text': 'Coins'},
#       {'indices': [47, 62], 'text': 'BitcoinPrivate'},
#       {'indices': [79, 84], 'text': 'SOTU'},
#       {'indices': [85, 101], 'text': 'StateofOurUnion'}],
#      'media': [{'display_url': 'pic.twitter.com/BnLtC58VSa',
#        'expanded_url': 'https://twitter.com/EDPressTV/status/958617967268376577/video/1',
#        'id': 958614974011723776,
#        'id_str': '958614974011723776',
#        'indices': [141, 164],
#        'media_url': 'http://pbs.twimg.com/ext_tw_video_thumb/958614974011723776/pu/img/LyIHRKK76u9h_UOo.jpg',
#        'media_url_https': 'https://pbs.twimg.com/ext_tw_video_thumb/958614974011723776/pu/img/LyIHRKK76u9h_UOo.jpg',
#        'sizes': {'large': {'h': 720, 'resize': 'fit', 'w': 1280},
#         'medium': {'h': 675, 'resize': 'fit', 'w': 1200},
#         'small': {'h': 383, 'resize': 'fit', 'w': 680},
#         'thumb': {'h': 150, 'resize': 'crop', 'w': 150}},
#        'type': 'video',
#        'url': 'https://t.co/BnLtC58VSa',
#        'video_info': {'aspect_ratio': [16, 9],
#         'duration_millis': 140000,
#         'variants': [{'bitrate': 2176000,
#           'content_type': 'video/mp4',
#           'url': 'https://video.twimg.com/ext_tw_video/958614974011723776/pu/vid/1280x720/0PI8_qhoaFbOEB14.mp4'},
#          {'bitrate': 256000,
#           'content_type': 'video/mp4',
#           'url': 'https://video.twimg.com/ext_tw_video/958614974011723776/pu/vid/320x180/HtCeFXV_1NgIZb3r.mp4'},
#          {'bitrate': 832000,
#           'content_type': 'video/mp4',
#           'url': 'https://video.twimg.com/ext_tw_video/958614974011723776/pu/vid/640x360/TDrvMPeOL67lJF9k.mp4'},
#          {'content_type': 'application/x-mpegURL',
#           'url': 'https://video.twimg.com/ext_tw_video/958614974011723776/pu/pl/DL4uCBpmey7xvNzk.m3u8'}]}}],
#      'symbols': [],
#      'urls': [{'display_url': 'bit.ly/2Bx63DF',
#        'expanded_url': 'http://bit.ly/2Bx63DF',
#        'indices': [117, 140],
#        'url': 'https://t.co/pIDfHLCW9x'}],
#      'user_mentions': [{'id': 3367334171,
#        'id_str': '3367334171',
#        'indices': [63, 69],
#        'name': 'Bitcoin News',
#        'screen_name': 'BTCTN'},
#       {'id': 357312062,
#        'id_str': '357312062',
#        'indices': [70, 78],
#        'name': 'Bitcoin',
#        'screen_name': 'Bitcoin'},
#       {'id': 437732648,
#        'id_str': '437732648',
#        'indices': [102, 115],
#        'name': 'Kaveh Taghvai',
#        'screen_name': 'KavehTaghvai'}]},
#     'extended_entities': {'media': [{'display_url': 'pic.twitter.com/BnLtC58VSa',
#        'expanded_url': 'https://twitter.com/EDPressTV/status/958617967268376577/video/1',
#        'id': 958614974011723776,
#        'id_str': '958614974011723776',
#        'indices': [141, 164],
#        'media_url': 'http://pbs.twimg.com/ext_tw_video_thumb/958614974011723776/pu/img/LyIHRKK76u9h_UOo.jpg',
#        'media_url_https': 'https://pbs.twimg.com/ext_tw_video_thumb/958614974011723776/pu/img/LyIHRKK76u9h_UOo.jpg',
#        'sizes': {'large': {'h': 720, 'resize': 'fit', 'w': 1280},
#         'medium': {'h': 675, 'resize': 'fit', 'w': 1200},
#         'small': {'h': 383, 'resize': 'fit', 'w': 680},
#         'thumb': {'h': 150, 'resize': 'crop', 'w': 150}},
#        'type': 'video',
#        'url': 'https://t.co/BnLtC58VSa',
#        'video_info': {'aspect_ratio': [16, 9],
#         'duration_millis': 140000,
#         'variants': [{'bitrate': 2176000,
#           'content_type': 'video/mp4',
#           'url': 'https://video.twimg.com/ext_tw_video/958614974011723776/pu/vid/1280x720/0PI8_qhoaFbOEB14.mp4'},
#          {'bitrate': 256000,
#           'content_type': 'video/mp4',
#           'url': 'https://video.twimg.com/ext_tw_video/958614974011723776/pu/vid/320x180/HtCeFXV_1NgIZb3r.mp4'},
#          {'bitrate': 832000,
#           'content_type': 'video/mp4',
#           'url': 'https://video.twimg.com/ext_tw_video/958614974011723776/pu/vid/640x360/TDrvMPeOL67lJF9k.mp4'},
#          {'content_type': 'application/x-mpegURL',
#           'url': 'https://video.twimg.com/ext_tw_video/958614974011723776/pu/pl/DL4uCBpmey7xvNzk.m3u8'}]}}]},
#     'full_text': 'The story of #bitcoin..\n#cryptocurrency #Coins #BitcoinPrivate @BTCTN @Bitcoin #SOTU\n#StateofOurUnion @KavehTaghvai \nhttps://t.co/pIDfHLCW9x https://t.co/BnLtC58VSa'},
#    'favorite_count': 2,
#    'favorited': False,
#    'filter_level': 'low',
#    'geo': None,
#    'id': 958617967268376577,
#    'id_str': '958617967268376577',
#    'in_reply_to_screen_name': None,
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'is_quote_status': False,
#    'lang': 'en',
#    'place': None,
#    'possibly_sensitive': False,
#    'quote_count': 0,
#    'reply_count': 0,
#    'retweet_count': 2,
#    'retweeted': False,
#    'source': '<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>',
#    'text': 'The story of #bitcoin..\n#cryptocurrency #Coins #BitcoinPrivate @BTCTN @Bitcoin #SOTU\n#StateofOurUnion @KavehTaghvai… https://t.co/OKC4Bzdouz',
#    'truncated': True,
#    'user': {'contributors_enabled': False,
#     'created_at': 'Wed Feb 15 09:24:21 +0000 2017',
#     'default_profile': False,
#     'default_profile_image': False,
#     'description': 'Economic Divide - A weekly look into economic issues around the globe - Hosted by @KavehTaghvai',
#     'favourites_count': 571,
#     'follow_request_sent': None,
#     'followers_count': 2318,
#     'following': None,
#     'friends_count': 24,
#     'geo_enabled': False,
#     'id': 831796279156015108,
#     'id_str': '831796279156015108',
#     'is_translator': False,
#     'lang': 'en',
#     'listed_count': 4,
#     'location': 'Islamic Republic of Iran',
#     'name': 'Economic Divide',
#     'notifications': None,
#     'profile_background_color': '000000',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/831796279156015108/1487333242',
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/945615434862260224/L6UOHaQw_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/945615434862260224/L6UOHaQw_normal.jpg',
#     'profile_link_color': '1B95E0',
#     'profile_sidebar_border_color': '000000',
#     'profile_sidebar_fill_color': '000000',
#     'profile_text_color': '000000',
#     'profile_use_background_image': False,
#     'protected': False,
#     'screen_name': 'EDPressTV',
#     'statuses_count': 863,
#     'time_zone': 'Pacific Time (US & Canada)',
#     'translator_type': 'none',
#     'url': 'http://www.presstv.com',
#     'utc_offset': -28800,
#     'verified': False}},
#   'source': '<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>',
#   'text': 'RT @EDPressTV: The story of #bitcoin..\n#cryptocurrency #Coins #BitcoinPrivate @BTCTN @Bitcoin #SOTU\n#StateofOurUnion @KavehTaghvai \nhttps:/…',
#   'truncated': False,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Wed Jan 01 06:33:27 +0000 2014',
#    'default_profile': False,
#    'default_profile_image': False,
#    'description': 'Tweets about latest incidents in the world & the Middle East',
#    'favourites_count': 4932,
#    'follow_request_sent': None,
#    'followers_count': 5568,
#    'following': None,
#    'friends_count': 170,
#    'geo_enabled': False,
#    'id': 2271266689,
#    'id_str': '2271266689',
#    'is_translator': False,
#    'lang': 'en',
#    'listed_count': 135,
#    'location': None,
#    'name': 'Meet The News',
#    'notifications': None,
#    'profile_background_color': 'C0DEED',
#    'profile_background_image_url': 'http://pbs.twimg.com/profile_background_images/378800000160533507/zQvxRBrD.jpeg',
#    'profile_background_image_url_https': 'https://pbs.twimg.com/profile_background_images/378800000160533507/zQvxRBrD.jpeg',
#    'profile_background_tile': True,
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/2271266689/1491200895',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/849140186642382848/QoNwoj0r_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/849140186642382848/QoNwoj0r_normal.jpg',
#    'profile_link_color': 'FF691F',
#    'profile_sidebar_border_color': 'FFFFFF',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'protected': False,
#    'screen_name': 'MeettheNews',
#    'statuses_count': 11284,
#    'time_zone': 'Tehran',
#    'translator_type': 'regular',
#    'url': None,
#    'utc_offset': 12600,
#    'verified': False}},
#  {'contributors': None,
#   'coordinates': None,
#   'created_at': 'Wed Jan 31 08:32:02 +0000 2018',
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'urls': [{'display_url': 'ift.tt/2DNckMU',
#      'expanded_url': 'http://ift.tt/2DNckMU',
#      'indices': [75, 98],
#      'url': 'https://t.co/0i1QX70rmK'},
#     {'display_url': 'ift.tt/2DNe2hi',
#      'expanded_url': 'http://ift.tt/2DNe2hi',
#      'indices': [99, 122],
#      'url': 'https://t.co/qHnGRc0w17'}],
#    'user_mentions': []},
#   'favorite_count': 0,
#   'favorited': False,
#   'filter_level': 'low',
#   'geo': None,
#   'id': 958618864824274944,
#   'id_str': '958618864824274944',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': False,
#   'lang': 'es',
#   'matching_rules': [{'tag': None}],
#   'place': None,
#   'possibly_sensitive': False,
#   'quote_count': 0,
#   'reply_count': 0,
#   'retweet_count': 0,
#   'retweeted': False,
#   'source': '<a href="https://ifttt.com" rel="nofollow">IFTTT</a>',
#   'text': 'Facebook prohíbe los anuncios de ICOs y criptomonedas, incluido el Bitcoin https://t.co/0i1QX70rmK https://t.co/qHnGRc0w17',
#   'truncated': False,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Tue Jun 23 07:10:09 +0000 2009',
#    'default_profile': False,
#    'default_profile_image': False,
#    'description': 'Hacemos #diseño #gráfico, #web, #marketing #digital y #fotografía. Nos apasiona la programación, la tecnología y la música.',
#    'favourites_count': 1809,
#    'follow_request_sent': None,
#    'followers_count': 3776,
#    'following': None,
#    'friends_count': 3143,
#    'geo_enabled': True,
#    'id': 49912640,
#    'id_str': '49912640',
#    'is_translator': False,
#    'lang': 'es',
#    'listed_count': 134,
#    'location': 'Argentina',
#    'name': 'UTWD',
#    'notifications': None,
#    'profile_background_color': '131516',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme14/bg.gif',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme14/bg.gif',
#    'profile_background_tile': True,
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/49912640/1514925359',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/948291652740935680/IiAOLnWN_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/948291652740935680/IiAOLnWN_normal.jpg',
#    'profile_link_color': '000000',
#    'profile_sidebar_border_color': 'FFFFFF',
#    'profile_sidebar_fill_color': 'C0DFEC',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'protected': False,
#    'screen_name': 'utwdesign',
#    'statuses_count': 58851,
#    'time_zone': 'Buenos Aires',
#    'translator_type': 'none',
#    'url': 'http://utwd.com.ar',
#    'utc_offset': -10800,
#    'verified': False}},
#  {'contributors': None,
#   'coordinates': None,
#   'created_at': 'Wed Jan 31 08:32:02 +0000 2018',
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'urls': [{'display_url': 'nyti.ms/2BGzK4p',
#      'expanded_url': 'http://nyti.ms/2BGzK4p',
#      'indices': [92, 115],
#      'url': 'https://t.co/Uwpl2lATUR'}],
#    'user_mentions': [{'id': 807095,
#      'id_str': '807095',
#      'indices': [3, 11],
#      'name': 'The New York Times',
#      'screen_name': 'nytimes'}]},
#   'favorite_count': 0,
#   'favorited': False,
#   'filter_level': 'low',
#   'geo': None,
#   'id': 958618864224489472,
#   'id_str': '958618864224489472',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': False,
#   'lang': 'en',
#   'matching_rules': [{'tag': None}],
#   'place': None,
#   'possibly_sensitive': False,
#   'quote_count': 0,
#   'reply_count': 0,
#   'retweet_count': 0,
#   'retweeted': False,
#   'retweeted_status': {'contributors': None,
#    'coordinates': None,
#    'created_at': 'Wed Jan 31 08:16:05 +0000 2018',
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'urls': [{'display_url': 'nyti.ms/2BGzK4p',
#       'expanded_url': 'http://nyti.ms/2BGzK4p',
#       'indices': [79, 102],
#       'url': 'https://t.co/Uwpl2lATUR'}],
#     'user_mentions': []},
#    'favorite_count': 179,
#    'favorited': False,
#    'filter_level': 'low',
#    'geo': None,
#    'id': 958614851659747329,
#    'id_str': '958614851659747329',
#    'in_reply_to_screen_name': None,
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'is_quote_status': False,
#    'lang': 'en',
#    'place': None,
#    'possibly_sensitive': False,
#    'quote_count': 0,
#    'reply_count': 41,
#    'retweet_count': 110,
#    'retweeted': False,
#    'source': '<a href="http://www.socialflow.com" rel="nofollow">SocialFlow</a>',
#    'text': 'Facebook said that it would ban all ads for Bitcoin and other cryptocurrencies https://t.co/Uwpl2lATUR',
#    'truncated': False,
#    'user': {'contributors_enabled': False,
#     'created_at': 'Fri Mar 02 20:41:42 +0000 2007',
#     'default_profile': False,
#     'default_profile_image': False,
#     'description': 'Where the conversation begins. Follow for breaking news, special reports, RTs of our journalists and more. Visit http://nyti.ms/2io2WFI to share news tips.',
#     'favourites_count': 16162,
#     'follow_request_sent': None,
#     'followers_count': 41016695,
#     'following': None,
#     'friends_count': 886,
#     'geo_enabled': False,
#     'id': 807095,
#     'id_str': '807095',
#     'is_translator': False,
#     'lang': 'en',
#     'listed_count': 194116,
#     'location': 'New York City',
#     'name': 'The New York Times',
#     'notifications': None,
#     'profile_background_color': '131516',
#     'profile_background_image_url': 'http://pbs.twimg.com/profile_background_images/736339684/948f072cc2da4e3a5e9f2ebfb3b1a0e7.png',
#     'profile_background_image_url_https': 'https://pbs.twimg.com/profile_background_images/736339684/948f072cc2da4e3a5e9f2ebfb3b1a0e7.png',
#     'profile_background_tile': True,
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/807095/1513258368',
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/942784892882112513/qV4xB0I3_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/942784892882112513/qV4xB0I3_normal.jpg',
#     'profile_link_color': '607696',
#     'profile_sidebar_border_color': 'FFFFFF',
#     'profile_sidebar_fill_color': 'EFEFEF',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'protected': False,
#     'screen_name': 'nytimes',
#     'statuses_count': 307846,
#     'time_zone': 'Eastern Time (US & Canada)',
#     'translator_type': 'none',
#     'url': 'http://www.nytimes.com/',
#     'utc_offset': -18000,
#     'verified': True}},
#   'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#   'text': 'RT @nytimes: Facebook said that it would ban all ads for Bitcoin and other cryptocurrencies https://t.co/Uwpl2lATUR',
#   'truncated': False,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Tue Jan 19 13:47:56 +0000 2016',
#    'default_profile': True,
#    'default_profile_image': False,
#    'description': "#ForeignAffairs #ForeignPolicy #politics #MediaNews #Breaking .#info, #media #MediaNews ,#Sport, ONLY #RT but aren't endorsemen't.",
#    'favourites_count': 7668,
#    'follow_request_sent': None,
#    'followers_count': 137,
#    'following': None,
#    'friends_count': 245,
#    'geo_enabled': False,
#    'id': 4783712292,
#    'id_str': '4783712292',
#    'is_translator': False,
#    'lang': 'en',
#    'listed_count': 1,
#    'location': None,
#    'name': 'NEWSROOM',
#    'notifications': None,
#    'profile_background_color': 'F5F8FA',
#    'profile_background_image_url': '',
#    'profile_background_image_url_https': '',
#    'profile_background_tile': False,
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/4783712292/1487692454',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/845479270893916160/TJslffd3_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/845479270893916160/TJslffd3_normal.jpg',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'protected': False,
#    'screen_name': 'Newsroom07',
#    'statuses_count': 13762,
#    'time_zone': None,
#    'translator_type': 'none',
#    'url': None,
#    'utc_offset': None,
#    'verified': False}},
#  {'contributors': None,
#   'coordinates': None,
#   'created_at': 'Wed Jan 31 08:32:02 +0000 2018',
#   'entities': {'hashtags': [{'indices': [78, 86], 'text': 'Bitcoin'},
#     {'indices': [87, 91], 'text': 'BTC'},
#     {'indices': [92, 103], 'text': 'BlockChain'},
#     {'indices': [104, 109], 'text': 'News'},
#     {'indices': [110, 125], 'text': 'CryptoCurrency'}],
#    'symbols': [],
#    'urls': [{'display_url': 'bitcoin-newswire.com/?p=19938',
#      'expanded_url': 'http://bitcoin-newswire.com/?p=19938',
#      'indices': [54, 77],
#      'url': 'https://t.co/mfMfCCr61l'}],
#    'user_mentions': []},
#   'favorite_count': 0,
#   'favorited': False,
#   'filter_level': 'low',
#   'geo': None,
#   'id': 958618864161644544,
#   'id_str': '958618864161644544',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': False,
#   'lang': 'en',
#   'matching_rules': [{'tag': None}],
#   'place': None,
#   'possibly_sensitive': False,
#   'quote_count': 0,
#   'reply_count': 0,
#   'retweet_count': 0,
#   'retweeted': False,
#   'source': '<a href="http://bitcoin-newswire.com" rel="nofollow">bitcoinnewswire</a>',
#   'text': 'SEC Directs Regulatory Fire at Initial Coin Offerings https://t.co/mfMfCCr61l #Bitcoin #BTC #BlockChain #News #CryptoCurrency',
#   'truncated': False,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Mon Dec 04 17:23:55 +0000 2017',
#    'default_profile': False,
#    'default_profile_image': False,
#    'description': 'Bitcoin Newswire is your bitcoin, btc news and crypto currency website.  We provide you with the latest bitcoin news from the  bitcoin and crypto markets.',
#    'favourites_count': 0,
#    'follow_request_sent': None,
#    'followers_count': 69,
#    'following': None,
#    'friends_count': 179,
#    'geo_enabled': False,
#    'id': 937734221182799872,
#    'id_str': '937734221182799872',
#    'is_translator': False,
#    'lang': 'en',
#    'listed_count': 0,
#    'location': 'New York, NY',
#    'name': 'Bitcoin Newswire',
#    'notifications': None,
#    'profile_background_color': '000000',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/937734221182799872/1512408655',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/937735378282405888/1jqSkrfu_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/937735378282405888/1jqSkrfu_normal.jpg',
#    'profile_link_color': 'FAB81E',
#    'profile_sidebar_border_color': '000000',
#    'profile_sidebar_fill_color': '000000',
#    'profile_text_color': '000000',
#    'profile_use_background_image': False,
#    'protected': False,
#    'screen_name': 'Bitcoin_NewsBTC',
#    'statuses_count': 9568,
#    'time_zone': None,
#    'translator_type': 'none',
#    'url': 'http://bitcoin-newswire.com',
#    'utc_offset': None,
#    'verified': False}},
#  {'contributors': None,
#   'coordinates': None,
#   'created_at': 'Wed Jan 31 08:32:02 +0000 2018',
#   'display_text_range': [32, 140],
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'urls': [{'display_url': 'twitter.com/i/web/status/9…',
#      'expanded_url': 'https://twitter.com/i/web/status/958618863805100032',
#      'indices': [117, 140],
#      'url': 'https://t.co/hXJxQojzyY'}],
#    'user_mentions': [{'id': 12683132,
#      'id_str': '12683132',
#      'indices': [0, 5],
#      'name': 'Laurent Raufaste',
#      'screen_name': '_LR_'},
#     {'id': 2794894848,
#      'id_str': '2794894848',
#      'indices': [6, 15],
#      'name': 'Bread',
#      'screen_name': 'breadapp'},
#     {'id': 3009858875,
#      'id_str': '3009858875',
#      'indices': [16, 31],
#      'name': 'Samourai Wallet',
#      'screen_name': 'SamouraiWallet'}]},
#   'extended_tweet': {'display_text_range': [32, 227],
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'urls': [],
#     'user_mentions': [{'id': 12683132,
#       'id_str': '12683132',
#       'indices': [0, 5],
#       'name': 'Laurent Raufaste',
#       'screen_name': '_LR_'},
#      {'id': 2794894848,
#       'id_str': '2794894848',
#       'indices': [6, 15],
#       'name': 'Bread',
#       'screen_name': 'breadapp'},
#      {'id': 3009858875,
#       'id_str': '3009858875',
#       'indices': [16, 31],
#       'name': 'Samourai Wallet',
#       'screen_name': 'SamouraiWallet'}]},
#    'full_text': "@_LR_ @breadapp @SamouraiWallet Missed Bitcoin fork and didn't get bictoin cash for free? Here is another chance to claim it. If you had balance on your BTC wallet 25-01-2018 you can get free Bitcoin Cash at rate 1 BTC = 1 BCH."},
#   'favorite_count': 0,
#   'favorited': False,
#   'filter_level': 'low',
#   'geo': None,
#   'id': 958618863805100032,
#   'id_str': '958618863805100032',
#   'in_reply_to_screen_name': '_LR_',
#   'in_reply_to_status_id': 958591320141987841,
#   'in_reply_to_status_id_str': '958591320141987841',
#   'in_reply_to_user_id': 12683132,
#   'in_reply_to_user_id_str': '12683132',
#   'is_quote_status': False,
# ...
#   'truncated': False,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Wed Jan 31 07:57:04 +0000 2018',
#    'default_profile': True,
#    'default_profile_image': False,
#    'description': 'Follow me. Follow back',
#    'favourites_count': 4,
#    'follow_request_sent': None,
#    'followers_count': 0,
#    'following': None,
#    'friends_count': 31,
#    'geo_enabled': False,
#    'id': 958610065694445569,
#    'id_str': '958610065694445569',
#    'is_translator': False,
#    'lang': 'en',
#    'listed_count': 0,
#    'location': None,
#    'name': 'Cointoken',
#    'notifications': None,
#    'profile_background_color': 'F5F8FA',
#    'profile_background_image_url': '',
#    'profile_background_image_url_https': '',
#    'profile_background_tile': False,
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/958610065694445569/1517386073',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/958612484276891648/Aa9VSiL2_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/958612484276891648/Aa9VSiL2_normal.jpg',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'protected': False,
#    'screen_name': 'Cointokenn',
#    'statuses_count': 25,
#    'time_zone': None,
#    'translator_type': 'none',
#    'url': None,
#    'utc_offset': None,
#    'verified': False}},
#  {'contributors': None,
#   'coordinates': None,
#   'created_at': 'Wed Jan 31 08:31:34 +0000 2018',
#   'display_text_range': [0, 88],
#   'entities': {'hashtags': [],
#    'media': [{'display_url': 'pic.twitter.com/UMb4XYPx8G',
#      'expanded_url': 'https://twitter.com/cryptograbber/status/958618746754617344/photo/1',
#      'id': 958618743415820288,
#      'id_str': '958618743415820288',
#      'indices': [89, 112],
#      'media_url': 'http://pbs.twimg.com/media/DU2yqwxU0AA2XwW.jpg',
#      'media_url_https': 'https://pbs.twimg.com/media/DU2yqwxU0AA2XwW.jpg',
#      'sizes': {'large': {'h': 713, 'resize': 'fit', 'w': 1000},
#       'medium': {'h': 713, 'resize': 'fit', 'w': 1000},
#       'small': {'h': 485, 'resize': 'fit', 'w': 680},
#       'thumb': {'h': 150, 'resize': 'crop', 'w': 150}},
#      'type': 'photo',
#      'url': 'https://t.co/UMb4XYPx8G'}],
#    'symbols': [],
#    'urls': [{'display_url': 'helpscoin.cryptograbber.com/?p=2601756',
#      'expanded_url': 'http://helpscoin.cryptograbber.com/?p=2601756',
#      'indices': [65, 88],
#      'url': 'https://t.co/CaZFPoxcxz'}],
#    'user_mentions': []},
#   'extended_entities': {'media': [{'display_url': 'pic.twitter.com/UMb4XYPx8G',
#      'expanded_url': 'https://twitter.com/cryptograbber/status/958618746754617344/photo/1',
#      'id': 958618743415820288,
#      'id_str': '958618743415820288',
#      'indices': [89, 112],
#      'media_url': 'http://pbs.twimg.com/media/DU2yqwxU0AA2XwW.jpg',
#      'media_url_https': 'https://pbs.twimg.com/media/DU2yqwxU0AA2XwW.jpg',
#      'sizes': {'large': {'h': 713, 'resize': 'fit', 'w': 1000},
#       'medium': {'h': 713, 'resize': 'fit', 'w': 1000},
#       'small': {'h': 485, 'resize': 'fit', 'w': 680},
#       'thumb': {'h': 150, 'resize': 'crop', 'w': 150}},
#      'type': 'photo',
#      'url': 'https://t.co/UMb4XYPx8G'}]},
#   'favorite_count': 0,
#   'favorited': False,
#   'filter_level': 'low',
#   'geo': None,
#   'id': 958618746754617344,
#   'id_str': '958618746754617344',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': False,
#   'lang': 'en',
#   'matching_rules': [{'tag': None}],
#   'place': None,
#   'possibly_sensitive': False,
#   'quote_count': 0,
#   'reply_count': 0,
#   'retweet_count': 0,
#   'retweeted': False,
#   'source': '<a href="http://publicize.wp.com/" rel="nofollow">WordPress.com</a>',
#   'text': 'NIST Paper Claims Bitcoin Cash Is “Technically” the Real Bitcoin https://t.co/CaZFPoxcxz https://t.co/UMb4XYPx8G',
#   'truncated': False,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Fri Jan 02 21:05:49 +0000 2015',
#    'default_profile': False,
#    'default_profile_image': False,
#    'description': 'Cryptotize your Life...',
#    'favourites_count': 1131,
#    'follow_request_sent': None,
#    'followers_count': 674,
#    'following': None,
#    'friends_count': 15,
#    'geo_enabled': False,
#    'id': 2957304731,
#    'id_str': '2957304731',
#    'is_translator': False,
#    'lang': 'de',
#    'listed_count': 1303,
#    'location': 'International',
#    'name': 'Cryptograbber',
#    'notifications': None,
#    'profile_background_color': 'FFCC4D',
#    'profile_background_image_url': 'http://pbs.twimg.com/profile_background_images/584828801013518337/9nixUrMf.png',
#    'profile_background_image_url_https': 'https://pbs.twimg.com/profile_background_images/584828801013518337/9nixUrMf.png',
#    'profile_background_tile': True,
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/2957304731/1420237071',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/551125275790934018/zT2RXVDs_normal.png',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/551125275790934018/zT2RXVDs_normal.png',
#    'profile_link_color': 'FFCC4D',
#    'profile_sidebar_border_color': '000000',
#    'profile_sidebar_fill_color': '000000',
#    'profile_text_color': '000000',
#    'profile_use_background_image': True,
#    'protected': False,
#    'screen_name': 'cryptograbber',
#    'statuses_count': 92585,
#    'time_zone': 'Pacific Time (US & Canada)',
#    'translator_type': 'none',
#    'url': 'https://cointracking.info?ref=Discount1',
#    'utc_offset': -28800,
#    'verified': False}},
#  {'contributors': None,
#   'coordinates': None,
#   'created_at': 'Wed Jan 31 08:31:33 +0000 2018',
#   'display_text_range': [0, 140],
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'urls': [{'display_url': 'twitter.com/i/web/status/9…',
#      'expanded_url': 'https://twitter.com/i/web/status/958618744787529728',
#      'indices': [117, 140],
#      'url': 'https://t.co/ObI9qqS3yO'}],
#    'user_mentions': []},
#   'extended_tweet': {'display_text_range': [0, 190],
#    'entities': {'hashtags': [{'indices': [149, 157], 'text': 'bitcoin'},
#      {'indices': [158, 170], 'text': 'bitcoincash'},
#      {'indices': [171, 180], 'text': 'ethereum'},
#      {'indices': [181, 190], 'text': 'litecoin'}],
#     'media': [{'display_url': 'pic.twitter.com/uyjVPLVMar',
#       'expanded_url': 'https://twitter.com/bitcoincasinoz1/status/958618744787529728/photo/1',
#       'id': 958618543225962496,
#       'id_str': '958618543225962496',
#       'indices': [191, 214],
#       'media_url': 'http://pbs.twimg.com/media/DU2yfHAWAAA_KLv.jpg',
#       'media_url_https': 'https://pbs.twimg.com/media/DU2yfHAWAAA_KLv.jpg',
#       'sizes': {'large': {'h': 900, 'resize': 'fit', 'w': 800},
#        'medium': {'h': 900, 'resize': 'fit', 'w': 800},
#        'small': {'h': 680, 'resize': 'fit', 'w': 604},
#        'thumb': {'h': 150, 'resize': 'crop', 'w': 150}},
#       'type': 'photo',
#       'url': 'https://t.co/uyjVPLVMar'}],
#     'symbols': [],
#     'urls': [{'display_url': 'bitcoincasino.zone/exchange-decen…',
#       'expanded_url': 'http://bitcoincasino.zone/exchange-decentralizzati-sono-la-fine-di-binance-coinbase-e-altri-exchange-centralizzati/',
#       'indices': [125, 148],
#       'url': 'https://t.co/KoDA1GLeEq'}],
#     'user_mentions': []},
#    'extended_entities': {'media': [{'display_url': 'pic.twitter.com/uyjVPLVMar',
#       'expanded_url': 'https://twitter.com/bitcoincasinoz1/status/958618744787529728/photo/1',
#       'id': 958618543225962496,
#       'id_str': '958618543225962496',
#       'indices': [191, 214],
#       'media_url': 'http://pbs.twimg.com/media/DU2yfHAWAAA_KLv.jpg',
#       'media_url_https': 'https://pbs.twimg.com/media/DU2yfHAWAAA_KLv.jpg',
#       'sizes': {'large': {'h': 900, 'resize': 'fit', 'w': 800},
#        'medium': {'h': 900, 'resize': 'fit', 'w': 800},
#        'small': {'h': 680, 'resize': 'fit', 'w': 604},
#        'thumb': {'h': 150, 'resize': 'crop', 'w': 150}},
#       'type': 'photo',
#       'url': 'https://t.co/uyjVPLVMar'}]},
#    'full_text': "Perché exchange decentralizzati sono la fine di Binance, Coinbase, Bitfinex, Kraken etc. Leggi l'articolo per saperne di più https://t.co/KoDA1GLeEq #bitcoin #bitcoincash #ethereum #litecoin https://t.co/uyjVPLVMar"},
#   'favorite_count': 0,
#   'favorited': False,
#   'filter_level': 'low',
#   'geo': None,
#   'id': 958618744787529728,
#   'id_str': '958618744787529728',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': False,
#   'lang': 'it',
#   'matching_rules': [{'tag': None}],
#   'place': None,
#   'possibly_sensitive': False,
#   'quote_count': 0,
#   'reply_count': 1,
#   'retweet_count': 0,
#   'retweeted': False,
#   'source': '<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>',
#   'text': "Perché exchange decentralizzati sono la fine di Binance, Coinbase, Bitfinex, Kraken etc. Leggi l'articolo per saper… https://t.co/ObI9qqS3yO",
#   'truncated': True,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Wed Nov 29 06:59:44 +0000 2017',
#    'default_profile': False,
#    'default_profile_image': False,
#    'description': 'Bitcoin casinos reviews. Il migliore sito di recensioni di bitcoin, litecoin, ethereum, ripple, bitcoin cash casinò. Seguici per ricevere le ultime sui bonus ⚡️',
#    'favourites_count': 485,
#    'follow_request_sent': None,
#    'followers_count': 94,
#    'following': None,
#    'friends_count': 174,
#    'geo_enabled': False,
#    'id': 935765200950775808,
#    'id_str': '935765200950775808',
#    'is_translator': False,
#    'lang': 'en',
#    'listed_count': 4,
#    'location': 'Monaco',
#    'name': 'bitcoincasino.zone',
#    'notifications': None,
#    'profile_background_color': '000000',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/935765200950775808/1511942324',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/935776677950558208/I4mOLd9y_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/935776677950558208/I4mOLd9y_normal.jpg',
#    'profile_link_color': 'FAB81E',
#    'profile_sidebar_border_color': '000000',
#    'profile_sidebar_fill_color': '000000',
#    'profile_text_color': '000000',
#    'profile_use_background_image': False,
#    'protected': False,
#    'screen_name': 'bitcoincasinoz1',
#    'statuses_count': 350,
#    'time_zone': None,
#    'translator_type': 'none',
#    'url': 'https://bitcoincasino.zone',
#    'utc_offset': None,
#    'verified': False}},
#  {'contributors': None,
#   'coordinates': None,
#   'created_at': 'Wed Jan 31 08:31:33 +0000 2018',
#   'display_text_range': [89, 140],
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'urls': [{'display_url': 'twitter.com/i/web/status/9…',
#      'expanded_url': 'https://twitter.com/i/web/status/958618743189405696',
#      'indices': [117, 140],
#      'url': 'https://t.co/O2o7oR3rQE'}],
#    'user_mentions': [{'id': 889680426742284288,
#      'id_str': '889680426742284288',
#      'indices': [0, 10],
#      'name': 'CryptoGravity [BTCP]',
#      'screen_name': 'rr_crypto'},
#     {'id': 735248067943890944,
#      'id_str': '735248067943890944',
#      'indices': [11, 23],
#      'name': 'Entropyless',
#      'screen_name': 'Entropyless'},
#     {'id': 963317166,
#      'id_str': '963317166',
#      'indices': [24, 33],
#      'name': 'Rhett Creighton',
#      'screen_name': 'HeyRhett'},
#     {'id': 943179325578338305,
#      'id_str': '943179325578338305',
#      'indices': [34, 47],
#      'name': 'CryptoJake22',
#      'screen_name': 'CryptoJake22'},
#     {'id': 215493429,
#      'id_str': '215493429',
#      'indices': [48, 58],
#      'name': 'Tai Zen',
#      'screen_name': 'HeyTaiZen'},
#     {'id': 65731063,
#      'id_str': '65731063',
#      'indices': [59, 72],
#      'name': 'Reegan Lessie',
#      'screen_name': 'ReeganLessie'},
#     {'id': 941466099928809472,
#      'id_str': '941466099928809472',
#      'indices': [73, 88],
#      'name': 'Bitcoin Private',
#      'screen_name': 'bitcoinprivate'}]},
#   'extended_tweet': {'display_text_range': [89, 322],
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'urls': [],
#     'user_mentions': [{'id': 889680426742284288,
#       'id_str': '889680426742284288',
#       'indices': [0, 10],
#       'name': 'CryptoGravity [BTCP]',
#       'screen_name': 'rr_crypto'},
#      {'id': 735248067943890944,
#       'id_str': '735248067943890944',
#       'indices': [11, 23],
#       'name': 'Entropyless',
#       'screen_name': 'Entropyless'},
#      {'id': 963317166,
#       'id_str': '963317166',
#       'indices': [24, 33],
#       'name': 'Rhett Creighton',
#       'screen_name': 'HeyRhett'},
#      {'id': 943179325578338305,
#       'id_str': '943179325578338305',
#       'indices': [34, 47],
#       'name': 'CryptoJake22',
#       'screen_name': 'CryptoJake22'},
#      {'id': 215493429,
#       'id_str': '215493429',
#       'indices': [48, 58],
#       'name': 'Tai Zen',
#       'screen_name': 'HeyTaiZen'},
#      {'id': 65731063,
#       'id_str': '65731063',
#       'indices': [59, 72],
#       'name': 'Reegan Lessie',
#       'screen_name': 'ReeganLessie'},
#      {'id': 941466099928809472,
#       'id_str': '941466099928809472',
#       'indices': [73, 88],
#       'name': 'Bitcoin Private',
#       'screen_name': 'bitcoinprivate'}]},
#    'full_text': '@rr_crypto @Entropyless @HeyRhett @CryptoJake22 @HeyTaiZen @ReeganLessie @bitcoinprivate Successfully launch mainnet and 12 global exchanges start trades! If you have balance on your BTC wallet 2018-1-05 you can get FREE Bitcoin Gold (BTG) and spend without confirmations ! 1BTC=1 BTG More details and info: btg-claim. com'},
#   'favorite_count': 0,
#   'favorited': False,
#   'filter_level': 'low',
#   'geo': None,
#   'id': 958618743189405696,
#   'id_str': '958618743189405696',
#   'in_reply_to_screen_name': 'rr_crypto',
#   'in_reply_to_status_id': 958176247309307904,
#   'in_reply_to_status_id_str': '958176247309307904',
#   'in_reply_to_user_id': 889680426742284288,
#   'in_reply_to_user_id_str': '889680426742284288',
#   'is_quote_status': False,
#   'lang': 'en',
#   'matching_rules': [{'tag': None}],
#   'place': None,
#   'quote_count': 0,
#   'reply_count': 0,
#   'retweet_count': 0,
#   'retweeted': False,
#   'source': '<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>',
#   'text': '@rr_crypto @Entropyless @HeyRhett @CryptoJake22 @HeyTaiZen @ReeganLessie @bitcoinprivate Successfully launch mainne… https://t.co/O2o7oR3rQE',
#   'truncated': True,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Sat Aug 26 10:01:45 +0000 2017',
#    'default_profile': True,
#    'default_profile_image': False,
#    'description': None,
#    'favourites_count': 0,
#    'follow_request_sent': None,
#    'followers_count': 0,
#    'following': None,
#    'friends_count': 31,
#    'geo_enabled': False,
#    'id': 901384158202789888,
#    'id_str': '901384158202789888',
#    'is_translator': False,
#    'lang': 'ru',
#    'listed_count': 0,
#    'location': None,
#    'name': 'Алина Фёдорова',
#    'notifications': None,
#    'profile_background_color': 'F5F8FA',
#    'profile_background_image_url': '',
#    'profile_background_image_url_https': '',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://abs.twimg.com/sticky/default_profile_images/default_profile_normal.png',
#    'profile_image_url_https': 'https://abs.twimg.com/sticky/default_profile_images/default_profile_normal.png',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'protected': False,
#    'screen_name': 'fqJa1sHZWr4IrqH',
#    'statuses_count': 38,
#    'time_zone': None,
#    'translator_type': 'none',
#    'url': None,
#    'utc_offset': None,
#    'verified': False}}]

# %%
[print(tweet.all_text, end='\n\n') for tweet in tweets[0:10]];
# Out:
# https://t.co/kZCKmIig4A  New pump and dump telegram group. NO PRE PUMP. NO RANK BS. EQUAL CHANCE FOR ALL TO MAKE GREAT GAINS!! First pump at 500 members #crypto #pumpanddump #bitcoin #altcoins
#
# interesting predictions here about the potential of @eidoo_io https://t.co/pqUY2sJAU2 #edo #coinbase #wallet #crypto #Ethereum #blockchain #bitcoin
#
# 📢MEGA Announcement #Paccoin #Giveaway Prize is 2500000 #PACCOINS #PRIZE
# 📈💰🚀
# Conditions:
# 1 - Follow Subscribe to us
# 2 - Retweet and like this post
#
# The Lucky #Winner will randomly be selected at the end of the week through our online server. Follow #Bitcoin #cryptocurrency
#
# Samsung reportedly enters volume production for Bitcoin mining ASIC #DIGITIMES https://t.co/wjsP8je6UO
#
# The story of #bitcoin..
# #cryptocurrency #Coins #BitcoinPrivate @BTCTN @Bitcoin #SOTU
# #StateofOurUnion @KavehTaghvai
# https://t.co/pIDfHLCW9x https://t.co/BnLtC58VSa
#
# Facebook prohíbe los anuncios de ICOs y criptomonedas, incluido el Bitcoin https://t.co/0i1QX70rmK https://t.co/qHnGRc0w17
#
# Facebook said that it would ban all ads for Bitcoin and other cryptocurrencies https://t.co/Uwpl2lATUR
#
# SEC Directs Regulatory Fire at Initial Coin Offerings https://t.co/mfMfCCr61l #Bitcoin #BTC #BlockChain #News #CryptoCurrency
#
# @_LR_ @breadapp @SamouraiWallet Missed Bitcoin fork and didn't get bictoin cash for free? Here is another chance to claim it. If you had balance on your BTC wallet 25-01-2018 you can get free Bitcoin Cash at rate 1 BTC = 1 BCH.
#
# @bitnewsae Successfully launch mainnet and 12 global exchanges start trades! If you have balance on your BTC wallet 2018-1-05 you can get FREE Bitcoin Gold (BTG) and spend without confirmations ! 1BTC=1 BTG More details and info: btg-claim. com

# %%
#list comprehension
[print(tweet.created_at_datetime) for tweet in tweets[0:10]];
# Out:
# 2018-01-31 08:32:02
# 2018-01-31 08:32:02
# 2018-01-31 08:32:02
# 2018-01-31 08:32:02
# 2018-01-31 08:32:02
# 2018-01-31 08:32:02
# 2018-01-31 08:32:02
# 2018-01-31 08:32:02
# 2018-01-31 08:32:02
# 2018-01-31 08:32:01

# %%
for tweet in tweets[0:10]:
    print(tweet.created_at_datetime)
# Out:
# 2018-01-31 08:32:02
# 2018-01-31 08:32:02
# 2018-01-31 08:32:02
# 2018-01-31 08:32:02
# 2018-01-31 08:32:02
# 2018-01-31 08:32:02
# 2018-01-31 08:32:02
# 2018-01-31 08:32:02
# 2018-01-31 08:32:02
# 2018-01-31 08:32:01
